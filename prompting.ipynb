# %%
from src.rag_prompt import rag_inference
from src.query import *

query = "What is the assessment pattern in detail with all components of generative ai?"

chunks = query_qdrant(
    query=query,
    model_name="BAAI/bge-base-en-v1.5",
    collection_name="bge_base_v1_5_512_52",
)

answer = rag_inference(
    model_name="llama3.1:8b",
    retrieved_chunks=chunks,
    query=query
)

print(answer)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 6153.63it/s]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# The final grade will be determined by the marks or grades earned during the project's phase-wise evaluations and the end-term assessment. The grading will be conducted using the relative grading method outlined in the university's academic regulations.
#
# To be eligible for grading, students must achieve a minimum of 40% of the total marks upon completing all assessments listed in the table below:
#
# | Component | Weightage |
# | --- | --- |
# | Quiz | 20% |
# | Assignment 1 & 2 | 40% (2 x 20%) |
# | End-Sem Project | 40% |
#
# The quiz will be held on April last week and will consist of MCQ knowledge and programming-based questions. The assignment will be continuous assessment, with offline evaluation conducted after students explain their solution with a demo followed by viva.
#
# The end-semester project carries a weightage of 40%, with an expected effort of 20+ hours, and will be evaluated separately.

# %%
from src.rag_prompt import rag_inference
from src.query import *

query = "What is the assessment pattern in detail with all components of generative ai?"

chunks = query_chromadb(
    query=query,
    model_name="BAAI/bge-base-en-v1.5",
    collection_name="bge_base_v1_5_512_52",
)

answer = rag_inference(
    model_name="llama3.1:8b",
    retrieved_chunks=chunks,
    query=query
)

print(answer)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 7849.04it/s]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# The final grade will be determined by the marks or grades earned during the project's phase-wise evaluations and the end-term assessment. The grading will be conducted using the relative grading method outlined in the university's academic regulations.
#
# To be eligible for grading, students must achieve a minimum of 40% of the total marks upon completing all assessments listed in the table below:
#
# | Component | Weightage |
# | --- | --- |
# | Quiz | 20% |
# | Assignment 1 & 2 | 2x 20% = 40% |
# | End-Sem Project | 40% |
#
# The quiz will be held on April last week and will consist of 20 MCQ questions, each of 1 mark. The duration of the quiz will be 20-30 minutes.
#
# Assignment 1 & 2 will carry a weightage of 40% and will be evaluated continuously. Students will be asked to explain their solution with a demo followed by viva.
#
# The end-sem project will carry a weightage of 40% and is expected to be completed in the last week of the course. The project will include along coding solutions, presentations, demonstrations & viva.

# %%
from src.rag_prompt import rag_inference
from src.query import *

query = "What is the assessment pattern in detail with all components of generative ai?"

chunks = query_chromadb(
    query=query,
    model_name="BAAI/bge-base-en-v1.5",
    collection_name="bge_base_v1_5_512_52",
)

answer = rag_inference(
    model_name="gemma2:9b",
    retrieved_chunks=chunks,
    query=query
)

print(answer)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 6311.52it/s]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Here's the assessment breakdown for the Generative AI course:
#
# **Components:**
#
# * **Quiz (20%):**
#     * Multiple-choice questions covering knowledge and programming concepts.
#     * 20 questions, each worth 1 mark.
#     * Duration: 20-30 minutes.
# * **Assignments 1 & 2 (40% total):**
#     * Two programming assignments focusing on practical implementation of generative AI concepts.
#     * Offline evaluation with code demonstration and viva voce.
# * **End-Sem Project (40%):**
#     * Students work on a real-world problem requiring design and implementation of a generative AI solution.
#     * Includes prompt engineering, retrieval-augmented generation, model adaptation, or evaluation of generative outputs.
#     * Requires 20+ hours of effort.
#
# **Grading:**
#
# * Relative grading method outlined in the university's academic regulations.
# * Minimum 40% required to pass.
#
#
# Let me know if you have any other questions about the course content!

# %%
from src.rag_prompt import rag_inference
from src.query import *

query = "What is the assessment pattern in detail with all components of generative ai?"

chunks = query_chromadb(
    query=query,
    model_name="BAAI/bge-base-en-v1.5",
    collection_name="bge_base_v1_5_512_52",
)

answer = rag_inference(
    model_name="phi3:mini",
    retrieved_chunks=chunks,
    query=query
)

print(answer)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 6006.87it/s]
# BertModel LOAD REPORT from: BAAI/bge-base-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# The course employs a comprehensive grading system that includes both continuous and end-term evaluations. The total marks for the project are divided as follows: quizzes account for 20% (4 marks each, with durations of 20-30 minutes), assignment work accounts for another 20%, while all other assessments together make up a further 60%.
#
# The continuous evaluation includes two programming assignments worth 20% each and is conducted online. Students are expected to submit their solutions, which will be evaluated based on the code's functionality as well as its efficiency in solving problems related to generative ai models such as prompt engineering or retrieval-augmented generation techniques.
#
# The end-term assessment involves a comprehensive project report that constitutes 40% of the final grade, with an expected effort time of around 20+ hours and evaluation based on presentations, demonstrations, viva (oral examination), as well as written reports submitted by students to showcase their understanding and application skills.
#
# The course also includes experiential learning components that make up another 40% of the overall assessment weightage. These involve practical assignments wherein students apply generative ai concepts in real-world problem statements, which could include tasks like prompt engineering or model adaptation for specific use cases relevant to industry needs.
#
# The course outcomes (COs) associated with these components are as follows:
#
# 1. CO1 - Apply core large language model (LLM) concepts and effective prompting techniques through interactive theory sessions, tool demonstrations using platforms like ChatGPT or Copilot, and industry use-case studies for practical understanding of real-world applications. This outcome is assessed during the continuous evaluation components with programming assignments that require students to demonstrate their ability in applying LLM concepts effectively (co1 techniques).
#
# 2. CO2 - Analyze generative ai lifecycle models and architectures, choosing suitable ones based on application domains through mini-assignments wherein they justify why a particular model is the best fit for given use cases (c02 skill development). This outcome will be assessed during continuous evaluation components with programming assignments that require students to implement their chosen generative ai solutions.
#
# 3. CO3 - Evaluate ethical and responsible AI frameworks, applying them in designing safe, accountable, effective generative ai systems
